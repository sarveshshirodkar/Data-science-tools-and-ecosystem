# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [raw]
# exercise 2: create a markdown cell with title of the notebook

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [raw]
# exercise 3: create a markdown cell for an introduction

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [raw]
# exercise 10: Inset a markdown cell to list objectives

# %% [markdown]
# **Objectives** : (ⅰ) data science tools like Rstudio, watsonlabs, apache software (ii) data science languages like python, R,Scala (iii) API's, data sets (iv) working with jupyter labs (v) creating and uploading a repository on github.

# %% [raw]
# exercise 4: create a markdown cell to list data science languages

# %% [markdown]
# Some of the popular languages that Data Scientist use are:
# 1) Python
# 2) R
# 3) Scala
# 4) Java

# %% [raw]
# exercise 5: create a markdown cell to list data science libraries

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
# 1) Pandas
# 2) NumPy
# 3) SciPy
# 4) TenorFlow
# 5) Matplotlib

# %% [raw]
# exercise 6: create a markdown cell with a table of Data Science tools

# %% [markdown]
# DATA SCIENCE TOOLS|
# ------------------
# Rstudio|
# Apache Spark|
# Apache hadoop|

# %% [raw]
# exercise 7: create a markdown cell introducing arithmetic expression examples

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in python

# %% [raw]
# exercise 8: create a code cell to multiply and add numbers

# %%
# This is a simple arithmetic expression to multiply then add integers
(3*4)+5
# Out:
# 17

# %% [raw]
# exercise 9: create a code cell to convert minutes to hours

# %%
# This will convert 200 minutes to hours by dividing by 60
200/60
# Out:
# 3.3333333333333335

# %% [raw]
# exercise 11: create a markdown cell to indicate the Author's name

# %% [markdown]
# ## Author ##
